# %% [markdown]
# # R Jupyter Notebook
#
# 이 노트북은 R 프로그래밍을 위한 기본 설정과 예제입니다.

# %%
# R 버전 확인
print(R.version.string)
print("Hello, R in Jupyter!")

# %%
# 기본 데이터 분석 예제
data <- c(1, 2, 3, 4, 5)
mean(data)
sd(data)
