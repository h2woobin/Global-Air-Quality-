# %% [markdown]
# # R Jupyter Notebook
#
# Test

# %%
print(R.version.string)
print("Hello, R in Jupyter!")
# Out:
# [1] "R version 4.5.2 (2025-10-31 ucrt)"
# [1] "Hello, R in Jupyter!"

# %%
data <- c(1, 2, 3, 4, 5)
mean(data)
sd(data)
# Out:
# [1] 3
# [1] 1.581139
